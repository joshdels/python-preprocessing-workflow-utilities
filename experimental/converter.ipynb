# %% [markdown]
# ### This section is testing the conversion of DXF and GIS stuffs

# %%
import ezdxf

doc = ezdxf.readfile("../data/sample.dxf")
msp = doc.modelspace()

entity = msp.query("LINE")[0]
for e in msp:
    e.dxftype(), e.dxf.layer

# lines = [(e.dxf.start, e.dxf.end) for e in msp.query("CIRCLE")]
# lines[:10]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(
  figsize=(12,8)
)

for start, end in lines:
  ax.plot([start.x, end.x], [start.y, end.y], 'b')

ax.set_aspect('equal')
plt.show()
